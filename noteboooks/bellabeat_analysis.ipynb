# %%
print("Hello Analyst!")
# Out:
# Hello Analyst!

# %%
import pandas as pd

# %% [markdown]
# ## Period 1 Daily Activity Data - Initial Inspection
#
#
# - 457 rows and 14 columns
# - 35 unique users
# - Data covers 12 March 2016 to 12 April 2016 (32 calendar dates)
# - No null values found
# - No duplicate rows
# - No duplicate Id/ActivityDate combinations
# - Users contributed between 8 and 32 days of data
# - Median user contributed 12 days of data
# - ActivityDate was converted from string to datetime

# %%
df =pd.read_csv(r"C:\Users\ellio\Desktop\bellabeat_case_study\data\raw\fitbit_2016-03-12_to_2016-04-11\dailyActivity_merged.csv")

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    str
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
#  13  SedentaryMinutes          457 non-null    int64
# ...

# %%
df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# ...

# %%
df['Id'].nunique()
# Out:
# 35

# %%
df["Id"].value_counts()
# Out:
# Id
# 4020332650    32
# 4057192912    32
# 1503960366    19
# 1624580081    19
# 2347167796    15
# 4445114986    15
# 4702921684    15
# 6962181067    14
# 1844505072    12
# 1927972279    12
# 2022484408    12
# 2026352035    12
# 2320127002    12
# 2873212765    12
# 3977333714    12
# 4319703577    12
# 4558609924    12
# 5553957443    12
# 7007744171    12
# 7086361926    12
# 8253242879    12
# 8378563200    12
# 8792009665    12
# 8877689391    12
# 5577150313    11
# 8053475328    11
# 1644430081    10
# 3372868164    10
# 6117666160    10
# 6290855005    10
# 6391747486     9
# 6775888955     9
# 2891001357     8
# 4388161847     8
# 8583815059     8
# Name: count, dtype: int64

# %%
df["ActivityDate"] = pd.to_datetime(df["ActivityDate"])

# %%
df["ActivityDate"].dtype
# Out:
# dtype('<M8[us]')

# %%
df["ActivityDate"].min()
# Out:
# Timestamp('2016-03-12 00:00:00')

# %%
df["ActivityDate"].max()
# Out:
# Timestamp('2016-04-12 00:00:00')

# %%
df["ActivityDate"].max() - df["ActivityDate"].min()
# Out:
# Timedelta('31 days 00:00:00')

# %%
df["ActivityDate"].nunique()
# Out:
# 32

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 452    False
# 453    False
# 454    False
# 455    False
# 456    False
# Length: 457, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated(subset=["Id", "ActivityDate"]).sum()
# Out:
# np.int64(0)

# %%
user_days = df["Id"].value_counts()

# %%
user_days.describe()
# Out:
# count    35.000000
# mean     13.057143
# std       5.351981
# min       8.000000
# 25%      10.500000
# 50%      12.000000
# 75%      12.000000
# max      32.000000
# Name: count, dtype: float64

# %%
sleep = pd.read_csv(r"C:\Users\ellio\Desktop\bellabeat_case_study\data\raw\fitbit_2016-03-12_to_2016-04-11\minuteSleep_merged.csv")

# %%
sleep.head(20)
# Out:
#             Id                  date  value        logId
# 0   1503960366  3/13/2016 2:39:30 AM      1  11114919637
# 1   1503960366  3/13/2016 2:40:30 AM      1  11114919637
# 2   1503960366  3/13/2016 2:41:30 AM      1  11114919637
# 3   1503960366  3/13/2016 2:42:30 AM      1  11114919637
# 4   1503960366  3/13/2016 2:43:30 AM      1  11114919637
# 5   1503960366  3/13/2016 2:44:30 AM      1  11114919637
# 6   1503960366  3/13/2016 2:45:30 AM      2  11114919637
# 7   1503960366  3/13/2016 2:46:30 AM      2  11114919637
# 8   1503960366  3/13/2016 2:47:30 AM      1  11114919637
# 9   1503960366  3/13/2016 2:48:30 AM      1  11114919637
# 10  1503960366  3/13/2016 2:49:30 AM      2  11114919637
# 11  1503960366  3/13/2016 2:50:30 AM      2  11114919637
# 12  1503960366  3/13/2016 2:51:30 AM      1  11114919637
# 13  1503960366  3/13/2016 2:52:30 AM      1  11114919637
# 14  1503960366  3/13/2016 2:53:30 AM      1  11114919637
# ...

# %%
sleep.shape
# Out:
# (198559, 4)

# %%
sleep["value"].value_counts()
# Out:
# value
# 1    183526
# 2     13010
# 3      2023
# Name: count, dtype: int64

# %% [markdown]
# ## Period 1 Minute Sleep Data - Initial Inspection
#
# - 198,559 rows and 4 columns
# - One row represents one minute of sleep data for one user
# - Sleep state values:
#   - 1 = asleep
#   - 2 = restless
#   - 3 = awake
# - 23 unique users have recorded sleep data, compared with 35 users in the daily activity dataset.
# - 525 duplicate rows were identified and removed.
# - No null values were found.

# %%
sleep["Id"].nunique()
# Out:
# 23

# %%
sleep["date"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
sleep["date"] = pd.to_datetime(sleep["date"])

# %%
sleep["date"].dtype
# Out:
# dtype('<M8[us]')

# %%
sleep["date"].min()
# Out:
# Timestamp('2016-03-11 21:19:30')

# %%
sleep["date"].max()
# Out:
# Timestamp('2016-04-12 08:35:00')

# %%
sleep.duplicated().sum()
# Out:
# np.int64(525)

# %%
sleep[sleep.duplicated(keep=False)].head(10)
# Out:
#                Id                date  value        logId
# 79892  4319703577 2016-04-05 22:50:00      3  11344563687
# 79893  4319703577 2016-04-05 22:51:00      3  11344563687
# 79894  4319703577 2016-04-05 22:52:00      2  11344563687
# 79895  4319703577 2016-04-05 22:53:00      2  11344563687
# 79896  4319703577 2016-04-05 22:54:00      2  11344563687
# 79897  4319703577 2016-04-05 22:55:00      1  11344563687
# 79898  4319703577 2016-04-05 22:56:00      1  11344563687
# 79899  4319703577 2016-04-05 22:57:00      2  11344563687
# 79900  4319703577 2016-04-05 22:58:00      2  11344563687
# 79901  4319703577 2016-04-05 22:59:00      1  11344563687

# %%
sleep[
    (sleep["Id"] == 4319703577) &
    (sleep["date"] == "2016-04-05 22:50:00")
]
# Out:
#                Id                date  value        logId
# 79892  4319703577 2016-04-05 22:50:00      3  11344563687
# 80158  4319703577 2016-04-05 22:50:00      3  11344563687

# %%
sleep=sleep.drop_duplicates()

# %%
sleep.duplicated().sum()
# Out:
# np.int64(0)

# %%
sleep.isnull().sum()
# Out:
# Id       0
# date     0
# value    0
# logId    0
# dtype: int64

# %% [markdown]
# ## Period 2 - Daily Sleep Data: Initial Inspection
#
# **Period:** 12 April 2016 to 12 May 2016
#
# - 413 rows and 5 columns initially
# - 24 unique users
# - 31 unique dates
# - `SleepDay` converted from string to datetime
# - No null values found
# - 3 duplicate rows identified and removed
# - 410 rows remained after duplicate removal
# - Extreme low sleep-duration records were investigated and retained because there was insufficient evidence that they were erroneous

# %%
sleep_daily= pd.read_csv(r"C:\Users\ellio\Desktop\bellabeat_case_study\data\raw\fitbit_2016-04-12_to_2016-05-12\sleepDay_merged.csv")

# %%
sleep_daily.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
sleep_daily.shape
# Out:
# (413, 5)

# %%
sleep_daily["SleepDay"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
sleep_daily["SleepDay"] = pd.to_datetime(sleep_daily["SleepDay"])
# Out:
# C:\Users\ellio\AppData\Local\Temp\ipykernel_6100\3481005203.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sleep_daily["SleepDay"] = pd.to_datetime(sleep_daily["SleepDay"])

# %%
sleep_daily["SleepDay"] = pd.to_datetime(
    sleep_daily["SleepDay"],
    format="%m/%d/%Y %I:%M:%S %p"
)

# %%
sleep_daily["SleepDay"].dtype
# Out:
# dtype('<M8[us]')

# %%
sleep_daily.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  413 non-null    int64
#  1   SleepDay            413 non-null    datetime64[us]
#  2   TotalSleepRecords   413 non-null    int64
#  3   TotalMinutesAsleep  413 non-null    int64
#  4   TotalTimeInBed      413 non-null    int64
# dtypes: datetime64[us](1), int64(4)
# memory usage: 16.3 KB

# %%
sleep_daily.duplicated().sum()
# Out:
# np.int64(3)

# %%
sleep_daily.isnull().sum()
# Out:
# Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %%
sleep_daily[sleep_daily.duplicated(keep=False)]
# Out:
#              Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 160  4388161847 2016-05-05                  1                 471
# 161  4388161847 2016-05-05                  1                 471
# 222  4702921684 2016-05-07                  1                 520
# 223  4702921684 2016-05-07                  1                 520
# 379  8378563200 2016-04-25                  1                 388
# 380  8378563200 2016-04-25                  1                 388
#
#      TotalTimeInBed
# 160             495
# 161             495
# 222             543
# 223             543
# 379             402
# 380             402

# %%
sleep_daily = sleep_daily.drop_duplicates()

# %%
sleep_daily.duplicated().sum()
# Out:
# np.int64(0)

# %%
sleep_daily.shape
# Out:
# (410, 5)

# %%
sleep_daily.nunique()
# Out:
# Id                     24
# SleepDay               31
# TotalSleepRecords       3
# TotalMinutesAsleep    256
# TotalTimeInBed        242
# dtype: int64

# %%
sleep_daily["SleepDay"].max() - sleep_daily["SleepDay"].min()
# Out:
# Timedelta('30 days 00:00:00')

# %%
sleep_daily.describe()
# Out:
#                  Id                    SleepDay  TotalSleepRecords  \
# count  4.100000e+02                         410         410.000000
# mean   4.994963e+09  2016-04-26 11:38:55.609756           1.119512
# min    1.503960e+09         2016-04-12 00:00:00           1.000000
# 25%    3.977334e+09         2016-04-19 00:00:00           1.000000
# 50%    4.702922e+09         2016-04-27 00:00:00           1.000000
# 75%    6.962181e+09         2016-05-04 00:00:00           1.000000
# max    8.792010e+09         2016-05-12 00:00:00           3.000000
# std    2.060863e+09                         NaN           0.346636
#
#        TotalMinutesAsleep  TotalTimeInBed
# count          410.000000      410.000000
# mean           419.173171      458.482927
# min             58.000000       61.000000
# 25%            361.000000      403.750000
# 50%            432.500000      463.000000
# 75%            490.000000      526.000000
# max            796.000000      961.000000
# ...

# %%
mask = sleep_daily["TotalMinutesAsleep"] ==58
sleep_daily[mask]
# Out:
#              Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 338  7007744171 2016-05-01                  1                  58
#
#      TotalTimeInBed
# 338              61

# %%
sleep_daily.sort_values("TotalMinutesAsleep").head(10)
# Out:
#              Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 338  7007744171 2016-05-01                  1                  58
# 123  4319703577 2016-04-21                  1                  59
# 65   2320127002 2016-04-23                  1                  61
# 164  4388161847 2016-05-09                  1                  62
# 282  5577150313 2016-05-05                  1                  74
# 365  8053475328 2016-05-07                  1                  74
# 110  4020332650 2016-04-16                  1                  77
# 337  7007744171 2016-04-16                  1                  79
# 150  4388161847 2016-04-22                  1                  82
# 172  4445114986 2016-04-17                  1                  98
#
#      TotalTimeInBed
# 338              61
# 123              65
# 65               69
# 164              65
# 282              78
# 365              75
# 110              77
# 337              82
# 150              85
# 172             107

# %% [markdown]
# ## Period 2 - Daily Activity Data: Initial Inspection
#
# **Period:** 12 April 2016 to 12 May 2016
#
# - 940 rows and 15 columns
# - 33 unique users
# - 31 calendar dates
# - `ActivityDate` converted from string to datetime
# - No null values found
# - No duplicate rows found
# - Users contributed between 4 and 31 days of activity data
# - Median user contributed 31 days
# - Mean user contributed approximately 28.5 days
# - Most users had very complete activity data, although a small number had substantially fewer recorded days
#
# ### Data Quality Observations
#
# - 79 records contained exactly 1,440 sedentary minutes (24 hours).
# - 72 of these records also contained 0 total steps.
# - 7 records contained 1,440 sedentary minutes despite recording between roughly 3,000 and 12,000 steps.
# - These 7 records also showed 0 very active, fairly active, and lightly active minutes despite having substantial step counts and distances.
# - This suggests that `SedentaryMinutes` and the activity-intensity minute fields may contain incomplete or inconsistent tracking for some records.
# - These records will not automatically be removed because other fields, such as `TotalSteps`, distance, and calories, may still contain useful information.
# - Activity-minute and sedentary-minute fields should therefore be interpreted cautiously in later analysis.
# - 4 records contained 0 calories, which is physiologically implausible and likely reflects incomplete or missing tracking. These records should be treated cautiously in any calorie-based analysis.

# %%
activity_daily= pd.read_csv(r"C:\Users\ellio\Desktop\bellabeat_case_study\data\raw\fitbit_2016-04-12_to_2016-05-12\dailyActivity_merged.csv")

# %%
activity_daily.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
activity_daily.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    str
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
#  13  SedentaryMinutes          940 non-null    int64
# ...

# %%
activity_daily["ActivityDate"] = pd.to_datetime(activity_daily["ActivityDate"])

# %%
activity_daily["ActivityDate"].dtype
# Out:
# dtype('<M8[us]')

# %%
activity_daily.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##Find the date range

# %%
activity_daily["ActivityDate"].max() - activity_daily["ActivityDate"].min()
# Out:
# Timedelta('30 days 00:00:00')

# %%
print(activity_daily["ActivityDate"].max())
print(activity_daily["ActivityDate"].min())
# Out:
# 2016-05-12 00:00:00
# 2016-04-12 00:00:00

# %%
activity_daily["Id"].nunique()
# Out:
# 33

# %%
activity_daily["Id"].value_counts().describe()
# Out:
# count    33.000000
# mean     28.484848
# std       5.657524
# min       4.000000
# 25%      29.000000
# 50%      31.000000
# 75%      31.000000
# max      31.000000
# Name: count, dtype: float64

# %%
activity_daily.describe()
# Out:
#                  Id                ActivityDate    TotalSteps  TotalDistance  \
# count  9.400000e+02                         940    940.000000     940.000000
# mean   4.855407e+09  2016-04-26 06:53:37.021276   7637.910638       5.489702
# min    1.503960e+09         2016-04-12 00:00:00      0.000000       0.000000
# 25%    2.320127e+09         2016-04-19 00:00:00   3789.750000       2.620000
# 50%    4.445115e+09         2016-04-26 00:00:00   7405.500000       5.245000
# 75%    6.962181e+09         2016-05-04 00:00:00  10727.000000       7.712500
# max    8.877689e+09         2016-05-12 00:00:00  36019.000000      28.030001
# std    2.424805e+09                         NaN   5087.150742       3.924606
#
#        TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# count       940.000000                940.000000          940.000000
# mean          5.475351                  0.108171            1.502681
# ...

# %%
activity_daily.sort_values("TotalSteps").head(10)
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 908  8792009665   2016-05-10           0            0.0              0.0
# 654  6775888955   2016-04-12           0            0.0              0.0
# 642  6290855005   2016-04-29           0            0.0              0.0
# 30   1503960366   2016-05-12           0            0.0              0.0
# 893  8792009665   2016-04-25           0            0.0              0.0
# 742  7086361926   2016-04-17           0            0.0              0.0
# 347  4020332650   2016-04-13           0            0.0              0.0
# 610  6117666160   2016-04-25           0            0.0              0.0
# 104  1844505072   2016-04-24           0            0.0              0.0
# 663  6775888955   2016-04-21           0            0.0              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 908                       0.0                 0.0                       0.0
# ...

# %%
mask1 = activity_daily["SedentaryMinutes"] == 1440

# %%
mask1.sum()
# Out:
# np.int64(79)

# %%
activity_daily[mask1]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 30   1503960366   2016-05-12           0            0.0              0.0
# 104  1844505072   2016-04-24           0            0.0              0.0
# 105  1844505072   2016-04-25           0            0.0              0.0
# 106  1844505072   2016-04-26           0            0.0              0.0
# 112  1844505072   2016-05-02           0            0.0              0.0
# ..          ...          ...         ...            ...              ...
# 903  8792009665   2016-05-05           0            0.0              0.0
# 904  8792009665   2016-05-06           0            0.0              0.0
# 905  8792009665   2016-05-07           0            0.0              0.0
# 906  8792009665   2016-05-08           0            0.0              0.0
# 907  8792009665   2016-05-09           0            0.0              0.0
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
mask2 = (activity_daily["TotalSteps"] == 0) & (activity_daily["SedentaryMinutes"] == 1440)

# %%
mask2.sum()
# Out:
# np.int64(72)

# %%
mask3 = (activity_daily["TotalSteps"] > 0) & (activity_daily["SedentaryMinutes"] == 1440)

# %%
activity_daily[mask3]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 381  4319703577   2016-04-12        7753           5.20             5.20
# 412  4388161847   2016-04-12       10122           7.78             7.78
# 853  8583815059   2016-04-16        5319           4.15             4.15
# 854  8583815059   2016-04-17        3008           2.35             2.35
# 869  8583815059   2016-05-02        8469           6.61             6.61
# 870  8583815059   2016-05-03       12015           9.37             9.37
# 871  8583815059   2016-05-04        3588           2.80             2.80
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 381                       0.0                 0.0                       0.0
# 412                       0.0                 0.0                       0.0
# 853                       0.0                 0.0                       0.0
# 854                       0.0                 0.0                       0.0
# ...

# %%
activity_daily["Calories"].describe()
# Out:
# count     940.000000
# mean     2303.609574
# std       718.166862
# min         0.000000
# 25%      1828.500000
# 50%      2134.000000
# 75%      2793.250000
# max      4900.000000
# Name: Calories, dtype: float64

# %%
(activity_daily["Calories"] ==0).sum()
# Out:
# np.int64(4)

# %% [markdown]
# ### Analysis Scope
#
# Period 2 (12 April 2016 to 12 May 2016) was selected as the primary dataset for analysis.
#
# Period 2 provides more complete participant coverage and contains both daily activity and daily sleep data. Period 1 was inspected during the data preparation stage but was not included in the main analysis due to its lower data completeness.
#
# Focusing on Period 2 reduces unnecessary complexity while still providing a full month of Fitbit data from which meaningful user behaviour trends can be explored.

# %%
activity_daily["Id"].nunique()
# Out:
# 33

# %%
sleep_daily["Id"].nunique()
# Out:
# 24

# %%
activity_daily.loc[
    activity_daily["Id"].isin(sleep_daily["Id"]),"Id"
].nunique()
# Out:
# 24

# %%
activity_daily["ActivityDate"].head()
# Out:
# 0   2016-04-12
# 1   2016-04-13
# 2   2016-04-14
# 3   2016-04-15
# 4   2016-04-16
# Name: ActivityDate, dtype: datetime64[us]

# %%
sleep_daily["SleepDay"].head()
# Out:
# 0   2016-04-12
# 1   2016-04-13
# 2   2016-04-15
# 3   2016-04-16
# 4   2016-04-17
# Name: SleepDay, dtype: datetime64[us]

# %% [markdown]
# # Analyse
#
# ### Analysis Plan
#
# The analysis will focus on Period 2 data (12 April–12 May 2016).
#
# Main areas to explore:
# - Daily activity patterns, primarily using `TotalSteps`
# - Daily sleep patterns using `TotalMinutesAsleep`
# - Differences in activity and sleep across days of the week
# - A simple exploration of the relationship between sleep duration and activity, if the data can be aligned appropriately
#
# The analysis will prioritise clear, high-level trends rather than granular activity-intensity measures due to identified data-quality limitations.

# %% [markdown]
# ## Activity Patterns
#
# ### Initial Step Summary
#
# - Mean daily steps: approximately 7,638
# - Median daily steps: approximately 7,406
# - 25% of recorded days had 3,790 steps or fewer.
# - Daily step counts show substantial variation, with a standard deviation of approximately 5,082 steps.
# - Zero-step records and unusually high values are present and should be interpreted with the data-quality limitations identified during preparation.
#
# ### Steps by Day of Week
#
# Average daily steps were relatively consistent across the week. Saturday (8,153) and Tuesday (8,125) recorded the highest average step counts, while Sunday had the lowest average at 6,933 steps.
#
# There was no clear overall weekday-versus-weekend pattern, although Sunday showed noticeably lower activity than the other days.
#
# Users showed considerable differences in their typical activity levels. The median user averaged approximately 7,283 steps per day, while the middle 50% of users averaged between approximately 5,567 and 9,520 steps. Individual user averages ranged widely, from 916 to 16,040 steps per day.

# %%
activity_daily["TotalSteps"].describe()
# Out:
# count      940.000000
# mean      7637.910638
# std       5087.150742
# min          0.000000
# 25%       3789.750000
# 50%       7405.500000
# 75%      10727.000000
# max      36019.000000
# Name: TotalSteps, dtype: float64

# %%
activity_daily.groupby("Id")["ActivityDate"].count().sort_values()
# Out:
# Id
# 4057192912     4
# 2347167796    18
# 8253242879    19
# 3372868164    20
# 6775888955    26
# 7007744171    26
# 6117666160    28
# 6290855005    29
# 8792009665    29
# 5577150313    30
# 3977333714    30
# 1644430081    30
# 2320127002    31
# 1503960366    31
# 1624580081    31
# 1844505072    31
# 4388161847    31
# 4319703577    31
# 4020332650    31
# 2873212765    31
# 1927972279    31
# 2022484408    31
# 2026352035    31
# 5553957443    31
# 4445114986    31
# 4558609924    31
# 4702921684    31
# 6962181067    31
# 8053475328    31
# 7086361926    31
# 8378563200    31
# 8583815059    31
# 8877689391    31
# Name: ActivityDate, dtype: int64

# %%
activity_daily.groupby("Id")["ActivityDate"].count().sort_values().describe().round(2)
# Out:
# count    33.00
# mean     28.48
# std       5.66
# min       4.00
# 25%      29.00
# 50%      31.00
# 75%      31.00
# max      31.00
# Name: ActivityDate, dtype: float64

# %%
activity_daily["DayOfWeek"] = activity_daily["ActivityDate"].dt.day_name()

# %%
activity_daily[["ActivityDate", "DayOfWeek"]].head
# Out:
# <bound method NDFrame.head of     ActivityDate  DayOfWeek
# 0     2016-04-12    Tuesday
# 1     2016-04-13  Wednesday
# 2     2016-04-14   Thursday
# 3     2016-04-15     Friday
# 4     2016-04-16   Saturday
# ..           ...        ...
# 935   2016-05-08     Sunday
# 936   2016-05-09     Monday
# 937   2016-05-10    Tuesday
# 938   2016-05-11  Wednesday
# 939   2016-05-12   Thursday
#
# [940 rows x 2 columns]>

# %%
activity_daily.groupby("DayOfWeek")["TotalSteps"].mean().round(2)
# Out:
# DayOfWeek
# Friday       7448.23
# Monday       7780.87
# Saturday     8152.98
# Sunday       6933.23
# Thursday     7405.84
# Tuesday      8125.01
# Wednesday    7559.37
# Name: TotalSteps, dtype: float64

# %%
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# %%
avg_steps_by_day = activity_daily.groupby("DayOfWeek")["TotalSteps"].mean().round(2)

# %%
avg_steps_by_day = avg_steps_by_day.reindex(day_order)

# %%
avg_steps_by_day
# Out:
# DayOfWeek
# Monday       7780.87
# Tuesday      8125.01
# Wednesday    7559.37
# Thursday     7405.84
# Friday       7448.23
# Saturday     8152.98
# Sunday       6933.23
# Name: TotalSteps, dtype: float64

# %%
activity_daily.groupby("Id")["TotalSteps"].mean().round(2)
# Out:
# Id
# 1503960366    12116.74
# 1624580081     5743.90
# 1644430081     7282.97
# 1844505072     2580.06
# 1927972279      916.13
# 2022484408    11370.65
# 2026352035     5566.87
# 2320127002     4716.87
# 2347167796     9519.67
# 2873212765     7555.77
# 3372868164     6861.65
# 3977333714    10984.57
# 4020332650     2267.23
# 4057192912     3838.00
# 4319703577     7268.84
# 4388161847    10813.94
# 4445114986     4796.55
# 4558609924     7685.13
# 4702921684     8572.06
# 5553957443     8612.58
# 5577150313     8304.43
# 6117666160     7046.71
# 6290855005     5649.55
# 6775888955     2519.69
# 6962181067     9794.81
# 7007744171    11323.42
# 7086361926     9371.77
# 8053475328    14763.29
# 8253242879     6482.16
# 8378563200     8717.71
# 8583815059     7198.52
# 8792009665     1853.72
# 8877689391    16040.03
# Name: TotalSteps, dtype: float64

# %%
avg_steps_by_user = activity_daily.groupby("Id")["TotalSteps"].mean().round(2)

# %%
avg_steps_by_user.describe().round(2)
# Out:
# count       33.00
# mean      7519.27
# std       3576.34
# min        916.13
# 25%       5566.87
# 50%       7282.97
# 75%       9519.67
# max      16040.03
# Name: TotalSteps, dtype: float64

# %% [markdown]
# ## Sleep Patterns

# %%
sleep_daily["TotalMinutesAsleep"].describe()
# Out:
# count    410.000000
# mean     419.173171
# std      118.635918
# min       58.000000
# 25%      361.000000
# 50%      432.500000
# 75%      490.000000
# max      796.000000
# Name: TotalMinutesAsleep, dtype: float64

# %%
(sleep_daily["TotalMinutesAsleep"] / 60).describe().round(2)
# Out:
# count    410.00
# mean       6.99
# std        1.98
# min        0.97
# 25%        6.02
# 50%        7.21
# 75%        8.17
# max       13.27
# Name: TotalMinutesAsleep, dtype: float64

# %%
sleep_daily.groupby("Id")["TotalMinutesAsleep"].mean().sort_values().round(2)
# Out:
# Id
# 2320127002     61.00
# 7007744171     68.50
# 4558609924    127.60
# 3977333714    293.64
# 1644430081    294.00
# 8053475328    297.00
# 4020332650    349.38
# 6775888955    349.67
# 1503960366    360.28
# 4445114986    385.18
# 4388161847    400.17
# 1927972279    417.00
# 4702921684    417.48
# 5577150313    432.00
# 8792009665    435.67
# 8378563200    445.13
# 2347167796    446.80
# 6962181067    448.00
# 7086361926    453.12
# 5553957443    463.48
# 4319703577    476.65
# 6117666160    478.78
# 2026352035    506.18
# 1844505072    652.00
# Name: TotalMinutesAsleep, dtype: float64

# %%
avg_sleep_by_user = sleep_daily.groupby("Id")["TotalMinutesAsleep"].mean().round(2)

# %%
avg_sleep_by_user.describe().round(2)
# Out:
# count     24.00
# mean     377.45
# std      136.73
# min       61.00
# 25%      336.28
# 50%      417.24
# 75%      449.28
# max      652.00
# Name: TotalMinutesAsleep, dtype: float64

# %%
(avg_sleep_by_user /60).describe().round(2)
# Out:
# count    24.00
# mean      6.29
# std       2.28
# min       1.02
# 25%       5.60
# 50%       6.95
# 75%       7.49
# max      10.87
# Name: TotalMinutesAsleep, dtype: float64

# %%
sleep_daily.groupby("Id")["SleepDay"].count().sort_values()
# Out:
# Id
# 2320127002     1
# 7007744171     2
# 6775888955     3
# 1844505072     3
# 8053475328     3
# 1644430081     4
# 4558609924     5
# 1927972279     5
# 4020332650     8
# 8792009665    15
# 2347167796    15
# 6117666160    18
# 4388161847    23
# 7086361926    24
# 1503960366    25
# 4319703577    26
# 5577150313    26
# 4702921684    27
# 2026352035    28
# 3977333714    28
# 4445114986    28
# 5553957443    31
# 6962181067    31
# 8378563200    31
# Name: SleepDay, dtype: int64

# %%
sleep_daily.groupby("Id")["SleepDay"].count().describe().round(0)
# Out:
# count    24.0
# mean     17.0
# std      11.0
# min       1.0
# 25%       5.0
# 50%      20.0
# 75%      27.0
# max      31.0
# Name: SleepDay, dtype: float64

# %% [markdown]
# ### Sleep Summary
#
# - Across all 410 sleep records, mean sleep duration was approximately 419 minutes (7.0 hours), with a median of approximately 433 minutes (7.2 hours).
# - The middle 50% of sleep records ranged from approximately 6.0 to 8.2 hours.
# - Sleep data coverage varies substantially between users, with some users contributing only 1–5 sleep records while others contributed close to a full month.
# - Therefore, individual user sleep averages should be interpreted cautiously, particularly for users with very few recorded nights.
#
# ### Sleep by Day of Week
#
# Average sleep duration was fairly consistent across the week, generally between about 6.7 and 7.5 hours.
#
# Sleep events beginning Sunday had the highest average sleep duration at approximately 453 minutes (7.5 hours), while sleep events beginning Thursday had the lowest at approximately 401 minutes (6.7 hours).

# %% [markdown]
# ### Sleep and Activity Date Alignment
#
# According to the Fitabase data dictionary, `SleepDay` represents the date on which a sleep event started.
#
# Therefore, when exploring whether sleep duration is associated with activity on the following day, each sleep record will be matched with the participant's activity record for the next calendar day.
#
# For example, a sleep event beginning on 20 April will be compared with activity recorded on 21 April.
#
# This analysis will examine association only and will not imply that sleep duration causes changes in activity.

# %%
sleep_daily["SleepDayOfWeek"] = sleep_daily["SleepDay"].dt.day_name()

# %%
sleep_daily.head()
# Out:
#            Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366 2016-04-12                  1                 327
# 1  1503960366 2016-04-13                  2                 384
# 2  1503960366 2016-04-15                  1                 412
# 3  1503960366 2016-04-16                  2                 340
# 4  1503960366 2016-04-17                  1                 700
#
#    TotalTimeInBed SleepDayOfWeek
# 0             346        Tuesday
# 1             407      Wednesday
# 2             442         Friday
# 3             367       Saturday
# 4             712         Sunday

# %%
sleep_daily.groupby("SleepDayOfWeek")["TotalMinutesAsleep"].mean().round(2)
# Out:
# SleepDayOfWeek
# Friday       405.42
# Monday       419.50
# Saturday     419.07
# Sunday       452.75
# Thursday     401.30
# Tuesday      404.54
# Wednesday    434.68
# Name: TotalMinutesAsleep, dtype: float64

# %%
avg_sleep_by_day = sleep_daily.groupby("SleepDayOfWeek")["TotalMinutesAsleep"].mean().round(2)

# %%
avg_sleep_by_day = avg_sleep_by_day.reindex(day_order)

# %%
avg_sleep_by_day
# Out:
# SleepDayOfWeek
# Monday       419.50
# Tuesday      404.54
# Wednesday    434.68
# Thursday     401.30
# Friday       405.42
# Saturday     419.07
# Sunday       452.75
# Name: TotalMinutesAsleep, dtype: float64

# %%
(avg_sleep_by_day/60).round(2)
# Out:
# SleepDayOfWeek
# Monday       6.99
# Tuesday      6.74
# Wednesday    7.24
# Thursday     6.69
# Friday       6.76
# Saturday     6.98
# Sunday       7.55
# Name: TotalMinutesAsleep, dtype: float64

# %%
sleep_daily["NextDay"] = sleep_daily["SleepDay"] + pd.Timedelta(days=1)

# %%
sleep_daily[["SleepDay", "NextDay"]].head()
# Out:
#     SleepDay    NextDay
# 0 2016-04-12 2016-04-13
# 1 2016-04-13 2016-04-14
# 2 2016-04-15 2016-04-16
# 3 2016-04-16 2016-04-17
# 4 2016-04-17 2016-04-18

# %%
sleep_activity = sleep_daily.merge(
    activity_daily,
    left_on=["Id", "NextDay"],
    right_on=["Id", "ActivityDate"],
    how="inner"
)

# %%
sleep_activity.shape
# Out:
# (399, 22)

# %%
sleep_activity.head()
# Out:
#            Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366 2016-04-12                  1                 327
# 1  1503960366 2016-04-13                  2                 384
# 2  1503960366 2016-04-15                  1                 412
# 3  1503960366 2016-04-16                  2                 340
# 4  1503960366 2016-04-17                  1                 700
#
#    TotalTimeInBed SleepDayOfWeek    NextDay ActivityDate  TotalSteps  \
# 0             346        Tuesday 2016-04-13   2016-04-13       10735
# 1             407      Wednesday 2016-04-14   2016-04-14       10460
# 2             442         Friday 2016-04-16   2016-04-16       12669
# 3             367       Saturday 2016-04-17   2016-04-17        9705
# 4             712         Sunday 2016-04-18   2016-04-18       13019
#
#    TotalDistance  ...  VeryActiveDistance  ModeratelyActiveDistance  \
# 0           6.97  ...                1.57                      0.69
# ...

# %%
sleep_activity["TotalMinutesAsleep"].corr(sleep_activity["TotalSteps"])
# Out:
# np.float64(-0.14646176957952514)

# %%
import matplotlib.pyplot as plt

plt.scatter(
    sleep_activity["TotalMinutesAsleep"],
    sleep_activity["TotalSteps"]
)
plt.xlabel("Total Minutes Asleep")
plt.ylabel("Next-DayTotal Steps")
plt.title("Sleep Duration vs Next Day Steps")
plt.show()

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
activity_sleep_same_day = sleep_daily.merge(
    activity_daily,
    left_on=["Id", "SleepDay"],
    right_on=["Id", "ActivityDate"],
    how="inner"
)

# %%
activity_sleep_same_day.shape
# Out:
# (410, 22)

# %%
activity_sleep_same_day.head()
# Out:
#            Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366 2016-04-12                  1                 327
# 1  1503960366 2016-04-13                  2                 384
# 2  1503960366 2016-04-15                  1                 412
# 3  1503960366 2016-04-16                  2                 340
# 4  1503960366 2016-04-17                  1                 700
#
#    TotalTimeInBed SleepDayOfWeek    NextDay ActivityDate  TotalSteps  \
# 0             346        Tuesday 2016-04-13   2016-04-12       13162
# 1             407      Wednesday 2016-04-14   2016-04-13       10735
# 2             442         Friday 2016-04-16   2016-04-15        9762
# 3             367       Saturday 2016-04-17   2016-04-16       12669
# 4             712         Sunday 2016-04-18   2016-04-17        9705
#
#    TotalDistance  ...  VeryActiveDistance  ModeratelyActiveDistance  \
# 0           8.50  ...                1.88                      0.55
# ...

# %%
activity_sleep_same_day["TotalMinutesAsleep"].corr(activity_sleep_same_day["TotalSteps"])
# Out:
# np.float64(-0.19034391666763162)

# %%
import numpy as np

x = activity_sleep_same_day["TotalSteps"]
y = activity_sleep_same_day["TotalMinutesAsleep"] / 60

plt.scatter(x, y)

m, b = np.polyfit(x, y, 1)
plt.plot(x, m * x + b, color='red')

plt.xlabel("Total Steps")
plt.ylabel("Sleep Duration (Hours)")
plt.title("Daily Steps vs Sleep Duration")
plt.show()

# %% [markdown]
# ### Relationship Between Activity and Sleep
#
# Two relationships were explored:
#
# - Sleep duration and total steps on the following day showed a weak negative correlation (`r ≈ -0.15`).
# - Total steps during the day and sleep duration that night also showed a weak negative correlation (`r ≈ -0.19`).
#
# Scatter plots showed substantial variation and no strong linear relationship between daily step count and sleep duration.
#
# Overall, the Period 2 data does not provide evidence of a strong relationship between sleep duration and daily step count in either direction. These results show association only and should not be interpreted as causal.

# %% [markdown]
# ## Visualisations
#
# ### Average Steps by Day of Week

# %%
plt.bar(
    avg_steps_by_day.index,
    avg_steps_by_day.values
)
for i, value in enumerate(avg_steps_by_day.values):
    plt.text(i, value + 100, f"{value:.0f}", ha="center")
plt.ylabel("Average Daily Steps")
plt.title("Average Daily Steps by Weekday")
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(
    avg_sleep_by_day.index,
    avg_sleep_by_day.values /60
)
for i, value in enumerate(avg_sleep_by_day.values / 60):
    plt.text(i, value + 0.1, f"{value:.1f}", ha="center")
plt.ylabel("Average Sleep Duration (Hours)")
plt.title("Average Sleep Duration by Weekday")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Key Findings
#
# ### 1 Activity Patterns.
#
# Weekday activity was relatively consistent, at roughly 7,000 - 8,000 average daily steps. Average activity was slightly higher on Tuesdays and Saturdays with over 8,000 average daily steps. Sunday saw a lower daily average at roughly 6,900 steps.
#
# Despite the relatively stable weekday averages, there was substantial variation between users: 25% of users averaged below roughly 5,500 daily steps, while the top 25% averaged above roughly 9,500 daily steps.
#
# ### 2 Sleep Patterns.
#
# Across 410 sleep records from this period, the average sleep duration was approximately 7 hours, with a standard deviation of 2 hours.
#
# Average sleep duration across the week was relatively consistent, ranging from 6.7 - 7.5 hours. Wednesday and Sunday saw slightly higher average sleep durations of 7.2 and 7.5 hours respectively.
#
# It is important to note that the sleep data coverage varies substantially between users, with some users contributing only 1–5 sleep records while others contributed close to a full month.
#
# Therefore, individual user sleep averages should be interpreted cautiously, particularly for users with very few recorded entries.
#
#
# ### 3 Steps vs Sleep Relationship.
#
# Upon analysis, there was a very weak negative correlation between daily steps and daily sleep duration. This means we tended to see slightly lower sleep durations on days with higher activity.
#
# However, the correlation was very weak (r = -0.19), and the observations showed substantial variation. Therefore, the data does not provide strong evidence of a meaningful relationship between daily steps and sleep duration.
