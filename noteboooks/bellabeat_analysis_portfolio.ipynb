# %% [markdown]
# # Bellabeat Smart Device Usage Case Study
#
# ## Introduction
#
# Bellabeat is a wellness technology company that develops smart products designed to help users understand their activity, sleep and other health habits.
#
# This case study analyses Fitbit smart-device usage data to identify behavioural trends that could provide useful insights for Bellabeat.
#
# ## Business Task
#
# Analyse smart-device activity and sleep data to identify trends in user behaviour and develop evidence-based recommendations that could inform Bellabeat's product and marketing strategy.
#
# ### Key Questions
#
# 1. What trends can be identified in smart-device activity and sleep behaviour?
# 2. How might these trends apply to Bellabeat customers?
# 3. How could these insights inform Bellabeat's strategy?

# %% [markdown]
# ## Tools & Libraries
#
# This analysis was completed in Python using pandas for data preparation and analysis, NumPy for simple numerical calculations, and Matplotlib for visualisation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Prepare & Process
#
# Two Fitbit data periods were inspected. Period 1 was used as a preliminary data-quality review, while Period 2 was selected for the main analysis because it provided daily activity and daily sleep data over the same one-month timeframe.

# %% [markdown]
# ## Period 1 – Preliminary Inspection
#
# Period 1 was inspected to understand the structure and quality of the available Fitbit data. It is retained here as evidence of the preparation process, but the final analysis is scoped to Period 2.

# %% [markdown]
# ## Period 1 Daily Activity Data - Initial Inspection
#
#
# - 457 rows and 14 columns
# - 35 unique users
# - Data covers 12 March 2016 to 12 April 2016 (32 calendar dates)
# - No null values found
# - No duplicate rows
# - No duplicate Id/ActivityDate combinations
# - Users contributed between 8 and 32 days of data
# - Median user contributed 12 days of data
# - ActivityDate was converted from string to datetime

# %%
period1_activity = pd.read_csv(
    r"..\data\raw\fitbit_2016-03-12_to_2016-04-11\dailyActivity_merged.csv"
)

# %%
period1_activity.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %%
period1_activity.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    str
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
#  13  SedentaryMinutes          457 non-null    int64
#  14  Calories                  457 non-null    int64
# dtypes: float64(7), int64(7), str(1)
# memory usage: 53.7 KB

# %%
period1_activity.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  4.570000e+02    457.000000     457.000000       457.000000
# mean   4.628595e+09   6546.562363       4.663523         4.609847
# std    2.293781e+09   5398.493064       4.082072         4.068540
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.347168e+09   1988.000000       1.410000         1.280000
# 50%    4.057193e+09   5986.000000       4.090000         4.090000
# 75%    6.391747e+09  10198.000000       7.160000         7.110000
# max    8.877689e+09  28497.000000      27.530001        27.530001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                457.000000          457.000000                457.000000
# mean                   0.179427            1.180897                  0.478643
# std                    0.849232            2.487159                  0.830995
# min                    0.000000            0.000000                  0.000000
# 25%                    0.000000            0.000000                  0.000000
# 50%                    0.000000            0.000000                  0.020000
# 75%                    0.000000            1.310000                  0.670000
# max                    6.727057           21.920000                  6.400000
#
#        LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# count           457.000000               457.000000         457.000000
# mean              2.890197                 0.001904          16.623632
# std               2.237523                 0.008487          28.919704
# min               0.000000                 0.000000           0.000000
# 25%               0.870000                 0.000000           0.000000
# 50%               2.930000                 0.000000           0.000000
# 75%               4.460000                 0.000000          25.000000
# max              12.510000                 0.100000         202.000000
#
#        FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# count           457.000000            457.000000        457.000000
# mean             13.070022            170.070022        995.282276
# std              36.208635            122.205372        337.021404
# min               0.000000              0.000000         32.000000
# 25%               0.000000             64.000000        728.000000
# 50%               1.000000            181.000000       1057.000000
# 75%              16.000000            257.000000       1285.000000
# max             660.000000            720.000000       1440.000000
#
#           Calories
# count   457.000000
# mean   2189.452954
# std     815.484523
# min       0.000000
# 25%    1776.000000
# 50%    2062.000000
# 75%    2667.000000
# max    4562.000000

# %%
period1_activity["ActivityDate"] = pd.to_datetime(period1_activity["ActivityDate"])

print("Unique users:", period1_activity["Id"].nunique())
print("Date range:", period1_activity["ActivityDate"].min(), "to", period1_activity["ActivityDate"].max())
print("Duplicate rows:", period1_activity.duplicated().sum())
print(
    "Duplicate user/date combinations:",
    period1_activity.duplicated(subset=["Id", "ActivityDate"]).sum()
)
# Out:
# Unique users: 35
# Date range: 2016-03-12 00:00:00 to 2016-04-12 00:00:00
# Duplicate rows: 0
# Duplicate user/date combinations: 0

# %%
period1_user_days = period1_activity["Id"].value_counts()
period1_user_days.describe()
# Out:
# count    35.000000
# mean     13.057143
# std       5.351981
# min       8.000000
# 25%      10.500000
# 50%      12.000000
# 75%      12.000000
# max      32.000000
# Name: count, dtype: float64

# %% [markdown]
# ## Period 1 Minute Sleep Data - Initial Inspection
#
# - 198,559 rows and 4 columns
# - One row represents one minute of sleep data for one user
# - Sleep state values:
#   - 1 = asleep
#   - 2 = restless
#   - 3 = awake
# - 23 unique users have recorded sleep data, compared with 35 users in the daily activity dataset.
# - 525 duplicate rows were identified and removed.
# - No null values were found.

# %%
period1_sleep = pd.read_csv(
    r"..\data\raw\fitbit_2016-03-12_to_2016-04-11\minuteSleep_merged.csv"
)

# %%
period1_sleep.head()
# Out:
#            Id                  date  value        logId
# 0  1503960366  3/13/2016 2:39:30 AM      1  11114919637
# 1  1503960366  3/13/2016 2:40:30 AM      1  11114919637
# 2  1503960366  3/13/2016 2:41:30 AM      1  11114919637
# 3  1503960366  3/13/2016 2:42:30 AM      1  11114919637
# 4  1503960366  3/13/2016 2:43:30 AM      1  11114919637

# %%
period1_sleep["date"] = pd.to_datetime(period1_sleep["date"])

print("Rows and columns:", period1_sleep.shape)
print("Unique users:", period1_sleep["Id"].nunique())
print("Date range:", period1_sleep["date"].min(), "to", period1_sleep["date"].max())
print("Duplicate rows:", period1_sleep.duplicated().sum())
print("Null values:")
print(period1_sleep.isnull().sum())
# Out:
# Rows and columns: (198559, 4)
# Unique users: 23
# Date range: 2016-03-11 21:19:30 to 2016-04-12 08:35:00
# Duplicate rows: 525
# Null values:
# Id       0
# date     0
# value    0
# logId    0
# dtype: int64

# %% [markdown]
# ### Duplicate handling
#
# Period 1 minute-level sleep data contained 525 exact duplicate rows. An example was inspected to confirm the duplication before exact duplicates were removed.

# %%
period1_sleep[period1_sleep.duplicated(keep=False)].head(10)
# Out:
#                Id                date  value        logId
# 79892  4319703577 2016-04-05 22:50:00      3  11344563687
# 79893  4319703577 2016-04-05 22:51:00      3  11344563687
# 79894  4319703577 2016-04-05 22:52:00      2  11344563687
# 79895  4319703577 2016-04-05 22:53:00      2  11344563687
# 79896  4319703577 2016-04-05 22:54:00      2  11344563687
# 79897  4319703577 2016-04-05 22:55:00      1  11344563687
# 79898  4319703577 2016-04-05 22:56:00      1  11344563687
# 79899  4319703577 2016-04-05 22:57:00      2  11344563687
# 79900  4319703577 2016-04-05 22:58:00      2  11344563687
# 79901  4319703577 2016-04-05 22:59:00      1  11344563687

# %%
period1_sleep = period1_sleep.drop_duplicates()
print("Remaining duplicate rows:", period1_sleep.duplicated().sum())
# Out:
# Remaining duplicate rows: 0

# %% [markdown]
# ## Period 2 – Main Analysis Dataset
#
# Period 2 covers 12 April to 12 May 2016 and contains both daily activity and daily sleep data. This consistent one-month timeframe was selected as the primary scope for the final activity and sleep analyses.

# %% [markdown]
# ## Period 2 - Daily Sleep Data: Initial Inspection
#
# **Period:** 12 April 2016 to 12 May 2016
#
# - 413 rows and 5 columns initially
# - 24 unique users
# - 31 unique dates
# - `SleepDay` converted from string to datetime
# - No null values found
# - 3 duplicate rows identified and removed
# - 410 rows remained after duplicate removal
# - Extreme low sleep-duration records were investigated and retained because there was insufficient evidence that they were erroneous

# %%
sleep_daily = pd.read_csv(
    r"..\data\raw\fitbit_2016-04-12_to_2016-05-12\sleepDay_merged.csv"
)

# %%
sleep_daily.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
sleep_daily["SleepDay"] = pd.to_datetime(
    sleep_daily["SleepDay"],
    format="%m/%d/%Y %I:%M:%S %p"
)

# %%
sleep_daily.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  413 non-null    int64
#  1   SleepDay            413 non-null    datetime64[us]
#  2   TotalSleepRecords   413 non-null    int64
#  3   TotalMinutesAsleep  413 non-null    int64
#  4   TotalTimeInBed      413 non-null    int64
# dtypes: datetime64[us](1), int64(4)
# memory usage: 16.3 KB

# %% [markdown]
# ### Sleep-data validation
#
# The daily sleep table was checked for missing values and exact duplicates. Three duplicate rows were removed. Extremely short sleep records were also inspected; because there was insufficient evidence that they were data-entry errors, they were retained and treated as a limitation.

# %%
sleep_daily.duplicated().sum()
# Out:
# np.int64(3)

# %%
sleep_daily.isnull().sum()
# Out:
# Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %%
sleep_daily = sleep_daily.drop_duplicates()
print("Rows after duplicate removal:", sleep_daily.shape[0])
print("Remaining duplicates:", sleep_daily.duplicated().sum())
# Out:
# Rows after duplicate removal: 410
# Remaining duplicates: 0

# %%
sleep_daily.describe()
# Out:
#                  Id                    SleepDay  TotalSleepRecords  \
# count  4.100000e+02                         410         410.000000
# mean   4.994963e+09  2016-04-26 11:38:55.609756           1.119512
# min    1.503960e+09         2016-04-12 00:00:00           1.000000
# 25%    3.977334e+09         2016-04-19 00:00:00           1.000000
# 50%    4.702922e+09         2016-04-27 00:00:00           1.000000
# 75%    6.962181e+09         2016-05-04 00:00:00           1.000000
# max    8.792010e+09         2016-05-12 00:00:00           3.000000
# std    2.060863e+09                         NaN           0.346636
#
#        TotalMinutesAsleep  TotalTimeInBed
# count          410.000000      410.000000
# mean           419.173171      458.482927
# min             58.000000       61.000000
# 25%            361.000000      403.750000
# 50%            432.500000      463.000000
# 75%            490.000000      526.000000
# max            796.000000      961.000000
# std            118.635918      127.455140

# %%
sleep_daily.sort_values("TotalMinutesAsleep").head(10)
# Out:
#              Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 338  7007744171 2016-05-01                  1                  58
# 123  4319703577 2016-04-21                  1                  59
# 65   2320127002 2016-04-23                  1                  61
# 164  4388161847 2016-05-09                  1                  62
# 282  5577150313 2016-05-05                  1                  74
# 365  8053475328 2016-05-07                  1                  74
# 110  4020332650 2016-04-16                  1                  77
# 337  7007744171 2016-04-16                  1                  79
# 150  4388161847 2016-04-22                  1                  82
# 172  4445114986 2016-04-17                  1                  98
#
#      TotalTimeInBed
# 338              61
# 123              65
# 65               69
# 164              65
# 282              78
# 365              75
# 110              77
# 337              82
# 150              85
# 172             107

# %% [markdown]
# ## Period 2 - Daily Activity Data: Initial Inspection
#
# **Period:** 12 April 2016 to 12 May 2016
#
# - 940 rows and 15 columns
# - 33 unique users
# - 31 calendar dates
# - `ActivityDate` converted from string to datetime
# - No null values found
# - No duplicate rows found
# - Users contributed between 4 and 31 days of activity data
# - Median user contributed 31 days
# - Mean user contributed approximately 28.5 days
# - Most users had very complete activity data, although a small number had substantially fewer recorded days
#
# ### Data Quality Observations
#
# - 79 records contained exactly 1,440 sedentary minutes (24 hours).
# - 72 of these records also contained 0 total steps.
# - 7 records contained 1,440 sedentary minutes despite recording between roughly 3,000 and 12,000 steps.
# - These 7 records also showed 0 very active, fairly active, and lightly active minutes despite having substantial step counts and distances.
# - This suggests that `SedentaryMinutes` and the activity-intensity minute fields may contain incomplete or inconsistent tracking for some records.
# - These records will not automatically be removed because other fields, such as `TotalSteps`, distance, and calories, may still contain useful information.
# - Activity-minute and sedentary-minute fields should therefore be interpreted cautiously in later analysis.
# - 4 records contained 0 calories, which is physiologically implausible and likely reflects incomplete or missing tracking. These records should be treated cautiously in any calorie-based analysis.

# %%
activity_daily = pd.read_csv(
    r"..\data\raw\fitbit_2016-04-12_to_2016-05-12\dailyActivity_merged.csv"
)

# %%
activity_daily.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   13                   328               728      1985
# 1                   19                   217               776      1797
# 2                   11                   181              1218      1776
# 3                   34                   209               726      1745
# 4                   10                   221               773      1863

# %%
activity_daily["ActivityDate"] = pd.to_datetime(activity_daily["ActivityDate"])

print("Unique users:", activity_daily["Id"].nunique())
print("Date range:", activity_daily["ActivityDate"].min(), "to", activity_daily["ActivityDate"].max())
print("Duplicate rows:", activity_daily.duplicated().sum())
print("Null values:")
print(activity_daily.isnull().sum())
# Out:
# Unique users: 33
# Date range: 2016-04-12 00:00:00 to 2016-05-12 00:00:00
# Duplicate rows: 0
# Null values:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
activity_daily.describe()
# Out:
#                  Id                ActivityDate    TotalSteps  TotalDistance  \
# count  9.400000e+02                         940    940.000000     940.000000
# mean   4.855407e+09  2016-04-26 06:53:37.021276   7637.910638       5.489702
# min    1.503960e+09         2016-04-12 00:00:00      0.000000       0.000000
# 25%    2.320127e+09         2016-04-19 00:00:00   3789.750000       2.620000
# 50%    4.445115e+09         2016-04-26 00:00:00   7405.500000       5.245000
# 75%    6.962181e+09         2016-05-04 00:00:00  10727.000000       7.712500
# max    8.877689e+09         2016-05-12 00:00:00  36019.000000      28.030001
# std    2.424805e+09                         NaN   5087.150742       3.924606
#
#        TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# count       940.000000                940.000000          940.000000
# mean          5.475351                  0.108171            1.502681
# min           0.000000                  0.000000            0.000000
# 25%           2.620000                  0.000000            0.000000
# 50%           5.245000                  0.000000            0.210000
# 75%           7.710000                  0.000000            2.052500
# max          28.030001                  4.942142           21.920000
# std           3.907276                  0.619897            2.658941
#
#        ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# count                940.000000           940.000000               940.000000
# mean                   0.567543             3.340819                 0.001606
# min                    0.000000             0.000000                 0.000000
# 25%                    0.000000             1.945000                 0.000000
# 50%                    0.240000             3.365000                 0.000000
# 75%                    0.800000             4.782500                 0.000000
# max                    6.480000            10.710000                 0.110000
# std                    0.883580             2.040655                 0.007346
#
#        VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# count         940.000000           940.000000            940.000000
# mean           21.164894            13.564894            192.812766
# min             0.000000             0.000000              0.000000
# 25%             0.000000             0.000000            127.000000
# 50%             4.000000             6.000000            199.000000
# 75%            32.000000            19.000000            264.000000
# max           210.000000           143.000000            518.000000
# std            32.844803            19.987404            109.174700
#
#        SedentaryMinutes     Calories
# count        940.000000   940.000000
# mean         991.210638  2303.609574
# min            0.000000     0.000000
# 25%          729.750000  1828.500000
# 50%         1057.500000  2134.000000
# 75%         1229.500000  2793.250000
# max         1440.000000  4900.000000
# std          301.267437   718.166862

# %% [markdown]
# ### Activity-data quality investigation
#
# Records with exactly 1,440 sedentary minutes were investigated because this represents a full 24-hour day. Most of these records also had zero steps, while a small number contained substantial step counts but zero recorded active minutes. Zero-calorie records were also identified.
#
# These observations suggest incomplete or inconsistent tracking in some activity-intensity fields. The records were not automatically removed because other fields, particularly `TotalSteps`, could still contain useful information. The final analysis therefore prioritises step count and treats the affected activity-intensity fields cautiously.

# %%
full_sedentary_day = activity_daily["SedentaryMinutes"] == 1440
print("Records with 1,440 sedentary minutes:", full_sedentary_day.sum())

zero_steps_full_sedentary = (
    (activity_daily["TotalSteps"] == 0) &
    (activity_daily["SedentaryMinutes"] == 1440)
)
print("Of these, records with zero steps:", zero_steps_full_sedentary.sum())
# Out:
# Records with 1,440 sedentary minutes: 79
# Of these, records with zero steps: 72

# %%
activity_daily[
    (activity_daily["TotalSteps"] > 0) &
    (activity_daily["SedentaryMinutes"] == 1440)
]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 381  4319703577   2016-04-12        7753           5.20             5.20
# 412  4388161847   2016-04-12       10122           7.78             7.78
# 853  8583815059   2016-04-16        5319           4.15             4.15
# 854  8583815059   2016-04-17        3008           2.35             2.35
# 869  8583815059   2016-05-02        8469           6.61             6.61
# 870  8583815059   2016-05-03       12015           9.37             9.37
# 871  8583815059   2016-05-04        3588           2.80             2.80
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 381                       0.0                 0.0                       0.0
# 412                       0.0                 0.0                       0.0
# 853                       0.0                 0.0                       0.0
# 854                       0.0                 0.0                       0.0
# 869                       0.0                 0.0                       0.0
# 870                       0.0                 0.0                       0.0
# 871                       0.0                 0.0                       0.0
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 381                  0.0                      0.0                  0
# 412                  0.0                      0.0                  0
# 853                  0.0                      0.0                  0
# 854                  0.0                      0.0                  0
# 869                  0.0                      0.0                  0
# 870                  0.0                      0.0                  0
# 871                  0.0                      0.0                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 381                    0                     0              1440      2115
# 412                    0                     0              1440      2955
# 853                    0                     0              1440      2693
# 854                    0                     0              1440      2439
# 869                    0                     0              1440      2894
# 870                    0                     0              1440      3212
# 871                    0                     0              1440      2516

# %%
print("Records with zero calories:", (activity_daily["Calories"] == 0).sum())
# Out:
# Records with zero calories: 4

# %% [markdown]
# ## Analysis Scope
#
# The main analysis uses Period 2 (12 April to 12 May 2016). It provides a consistent one-month period containing both daily activity and daily sleep data, allowing the two behaviours to be explored separately and, where records align, together.
#
# Period 1 was retained as preliminary inspection data but was not required for the final scoped analysis. The analysis prioritises `TotalSteps` and `TotalMinutesAsleep`, while avoiding strong conclusions from activity-intensity fields affected by the data-quality issues identified above.

# %% [markdown]
# # Analyse
#
# The analysis addresses three questions:
#
# 1. How do daily activity levels vary across users and days of the week?
# 2. What patterns are visible in sleep duration and sleep-data coverage?
# 3. Is daily step count meaningfully associated with sleep duration?

# %% [markdown]
# ## Activity Patterns
#
# ### Initial Step Summary
#
# - Mean daily steps: approximately 7,638
# - Median daily steps: approximately 7,406
# - 25% of recorded days had 3,790 steps or fewer.
# - Daily step counts show substantial variation, with a standard deviation of approximately 5,082 steps.
# - Zero-step records and unusually high values are present and should be interpreted with the data-quality limitations identified during preparation.
#
# ### Steps by Day of Week
#
# Average daily steps were relatively consistent across the week. Saturday (8,153) and Tuesday (8,125) recorded the highest average step counts, while Sunday had the lowest average at 6,933 steps.
#
# There was no clear overall weekday-versus-weekend pattern, although Sunday showed noticeably lower activity than the other days.
#
# Users showed considerable differences in their typical activity levels. The median user averaged approximately 7,283 steps per day, while the middle 50% of users averaged between approximately 5,567 and 9,520 steps. Individual user averages ranged widely, from 916 to 16,040 steps per day.

# %%
activity_daily["TotalSteps"].describe()
# Out:
# count      940.000000
# mean      7637.910638
# std       5087.150742
# min          0.000000
# 25%       3789.750000
# 50%       7405.500000
# 75%      10727.000000
# max      36019.000000
# Name: TotalSteps, dtype: float64

# %%
activity_days_by_user = activity_daily.groupby("Id")["ActivityDate"].count()
activity_days_by_user.describe().round(2)
# Out:
# count    33.00
# mean     28.48
# std       5.66
# min       4.00
# 25%      29.00
# 50%      31.00
# 75%      31.00
# max      31.00
# Name: ActivityDate, dtype: float64

# %%
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

activity_daily["DayOfWeek"] = activity_daily["ActivityDate"].dt.day_name()

avg_steps_by_day = (
    activity_daily.groupby("DayOfWeek")["TotalSteps"]
    .mean()
    .reindex(day_order)
)

avg_steps_by_day.round(2)
# Out:
# DayOfWeek
# Monday       7780.87
# Tuesday      8125.01
# Wednesday    7559.37
# Thursday     7405.84
# Friday       7448.23
# Saturday     8152.98
# Sunday       6933.23
# Name: TotalSteps, dtype: float64

# %%
avg_steps_by_user = activity_daily.groupby("Id")["TotalSteps"].mean()
avg_steps_by_user.describe().round(2)
# Out:
# count       33.00
# mean      7519.27
# std       3576.34
# min        916.13
# 25%       5566.87
# 50%       7282.97
# 75%       9519.67
# max      16040.03
# Name: TotalSteps, dtype: float64

# %% [markdown]
# ### Average Steps by Day of Week

# %%
plt.bar(
    avg_steps_by_day.index,
    avg_steps_by_day.values
)
for i, value in enumerate(avg_steps_by_day.values):
    plt.text(i, value + 100, f"{value:.0f}", ha="center")
plt.ylabel("Average Daily Steps")
plt.title("Average Daily Steps by Weekday")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Sleep Patterns
#
# Sleep duration was analysed both across individual sleep records and across days of the week. User-level record counts were also reviewed because sleep-data coverage varied substantially between participants.

# %%
(sleep_daily["TotalMinutesAsleep"] / 60).describe().round(2)
# Out:
# count    410.00
# mean       6.99
# std        1.98
# min        0.97
# 25%        6.02
# 50%        7.21
# 75%        8.17
# max       13.27
# Name: TotalMinutesAsleep, dtype: float64

# %%
sleep_records_by_user = sleep_daily.groupby("Id")["SleepDay"].count()
sleep_records_by_user.describe().round(0)
# Out:
# count    24.0
# mean     17.0
# std      11.0
# min       1.0
# 25%       5.0
# 50%      20.0
# 75%      27.0
# max      31.0
# Name: SleepDay, dtype: float64

# %% [markdown]
# ### Sleep Summary
#
# - Across all 410 sleep records, mean sleep duration was approximately 419 minutes (7.0 hours), with a median of approximately 433 minutes (7.2 hours).
# - The middle 50% of sleep records ranged from approximately 6.0 to 8.2 hours.
# - Sleep data coverage varies substantially between users, with some users contributing only 1–5 sleep records while others contributed close to a full month.
# - Therefore, individual user sleep averages should be interpreted cautiously, particularly for users with very few recorded nights.
#
# ### Sleep by Day of Week
#
# Average sleep duration was fairly consistent across the week, generally between about 6.7 and 7.5 hours.
#
# Sleep events beginning Sunday had the highest average sleep duration at approximately 453 minutes (7.5 hours), while sleep events beginning Thursday had the lowest at approximately 401 minutes (6.7 hours).

# %%
sleep_daily["SleepDayOfWeek"] = sleep_daily["SleepDay"].dt.day_name()

avg_sleep_by_day = (
    sleep_daily.groupby("SleepDayOfWeek")["TotalMinutesAsleep"]
    .mean()
    .reindex(day_order)
)

(avg_sleep_by_day / 60).round(2)
# Out:
# SleepDayOfWeek
# Monday       6.99
# Tuesday      6.74
# Wednesday    7.24
# Thursday     6.69
# Friday       6.76
# Saturday     6.98
# Sunday       7.55
# Name: TotalMinutesAsleep, dtype: float64

# %% [markdown]
# ### Average Sleep Duration by Day of Week

# %%
plt.bar(
    avg_sleep_by_day.index,
    avg_sleep_by_day.values /60
)
for i, value in enumerate(avg_sleep_by_day.values / 60):
    plt.text(i, value + 0.1, f"{value:.1f}", ha="center")
plt.ylabel("Average Sleep Duration (Hours)")
plt.title("Average Sleep Duration by Weekday")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Activity and Sleep Relationship
#
# Daily activity and sleep records were matched by user and date to examine whether step count during a day was associated with sleep duration recorded for the corresponding sleep period. A next-day relationship was also explored as a secondary check.
#
# Correlation is used here only to describe association; it does not imply causation.

# %%
activity_sleep_same_day = sleep_daily.merge(
    activity_daily,
    left_on=["Id", "SleepDay"],
    right_on=["Id", "ActivityDate"],
    how="inner"
)

print("Matched same-day records:", activity_sleep_same_day.shape[0])
# Out:
# Matched same-day records: 410

# %%
same_day_correlation = activity_sleep_same_day["TotalMinutesAsleep"].corr(
    activity_sleep_same_day["TotalSteps"]
)
round(same_day_correlation, 2)
# Out:
# np.float64(-0.19)

# %%
x = activity_sleep_same_day["TotalSteps"]
y = activity_sleep_same_day["TotalMinutesAsleep"] / 60

plt.scatter(x, y)

m, b = np.polyfit(x, y, 1)
plt.plot(x, m * x + b, color='red')

plt.xlabel("Total Steps")
plt.ylabel("Sleep Duration (Hours)")
plt.title("Daily Steps vs Sleep Duration")
plt.show()

# %% [markdown]
# ### Relationship Between Activity and Sleep
#
# Two relationships were explored:
#
# - Sleep duration and total steps on the following day showed a weak negative correlation (`r ≈ -0.15`).
# - Total steps during the day and sleep duration that night also showed a weak negative correlation (`r ≈ -0.19`).
#
# Scatter plots showed substantial variation and no strong linear relationship between daily step count and sleep duration.
#
# Overall, the Period 2 data does not provide evidence of a strong relationship between sleep duration and daily step count in either direction. These results show association only and should not be interpreted as causal.

# %% [markdown]
# ## Key Findings
#
# ### 1. Activity Patterns
#
# Weekday activity was relatively consistent, at roughly 7,000 - 8,000 average daily steps. Average activity was slightly higher on Tuesdays and Saturdays with over 8,000 average daily steps. Sunday saw a lower daily average at roughly 6,900 steps.
#
# Despite the relatively stable weekday averages, there was substantial variation between users: 25% of users averaged below roughly 5,500 daily steps, while the top 25% averaged above roughly 9,500 daily steps.
#
# ### 2. Sleep Patterns
#
# Across 410 sleep records from this period, the average sleep duration was approximately 7 hours, with a standard deviation of 2 hours.
#
# Average sleep duration across the week was relatively consistent, ranging from 6.7 - 7.5 hours. Wednesday and Sunday saw slightly higher average sleep durations of 7.2 and 7.5 hours respectively.
#
# It is important to note that the sleep data coverage varies substantially between users, with some users contributing only 1–5 sleep records while others contributed close to a full month.
#
# Therefore, individual user sleep averages should be interpreted cautiously, particularly for users with very few recorded entries.
#
#
# ### 3. Steps vs Sleep Relationship
#
# Upon analysis, there was a very weak negative correlation between daily steps and daily sleep duration. This means we tended to see slightly lower sleep durations on days with higher activity.
#
# However, the correlation was very weak (r = -0.19), and the observations showed substantial variation. Therefore, the data does not provide strong evidence of a meaningful relationship between daily steps and sleep duration.

# %% [markdown]
# ## Recommendations
#
# ### 1. Personalised Activity Goals
#
# Daily activity was relatively consistent across weekdays, but activity levels varied substantially between individual users. Bellabeat could therefore provide personalised activity goals and benchmarks based on each user's own historical activity rather than relying primarily on generic step targets. Personalised goals could provide users with more achievable and relevant targets as their activity levels change over time.
#
# ### 2. Encourage Consistent Sleep Tracking
#
# Sleep data coverage varied substantially between users, with some users recording close to a full month of sleep data while others recorded only a few nights. Bellabeat could encourage regular sleep tracking through reminders and educational messaging that explains how more complete data enables meaningful personalised insights and trends over time.
#
# This could include in-app or wearable reminders for users whose sleep data has not been recorded consistently.
#
# ### 3. Treat Activity and Sleep as Distinct Wellness Measures
#
# The analysis found only a very weak relationship between daily steps and sleep duration (r = -0.19). Bellabeat should therefore avoid assuming that highly active users will necessarily have longer sleep. Activity and sleep could instead be monitored as distinct wellness measures, allowing users to receive insights based on their actual sleep patterns rather than their activity levels alone.

# %% [markdown]
# ## Limitations
#
# ### 1. Small sample size
# Our dataset contains only 33 users with activity data, and sleep data covers even fewer users. That is a very small sample size to gather insights and make claims for a much larger Bellabeat customer base.
#
# ### 2. Short observation period
# The dataset covers roughly one month. This is a limiting factor; a longer observation period could provide greater confidence in long-term behavioural patterns, account for seasonal variations and reduce the impact of short-term fluctuations.
#
# ### 3. Incomplete / Questionable records
# The amount of data provided by different users varied considerably, particularly for sleep data. We also came across implausible data such as extremely short sleep durations, as well as zero-calorie days. While the cause of these observations could not be determined, their presence reduces confidence in some of the data.
#
#
# ### 4. Limited demographic information
# This is very relevant to the Bellabeat target market. The age, gender, location and other demographic characteristics of the Fitbit users are unknown. This means we should be cautious about generalising these behavioural patterns to the Bellabeat customer base.

# %% [markdown]
# ## Conclusion
#
# The analysis found that average activity and sleep patterns were relatively stable across the week, but individual activity levels varied widely and sleep-data coverage differed considerably between users. Daily steps and sleep duration showed only a very weak relationship, suggesting that activity and sleep should be treated as distinct wellness measures rather than using one as a proxy for the other.
#
# For Bellabeat, the clearest opportunities from this analysis are to personalise activity goals using users' own historical behaviour, encourage more consistent sleep tracking, and provide activity and sleep insights independently. These recommendations should be interpreted within the limitations of the small sample, short observation period, incomplete records, and lack of demographic information.
